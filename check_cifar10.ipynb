# %%
# %matplotlib inline
import seaborn
import matplotlib.pyplot as plt
import cifar10
reload(cifar10)

fig, axies = plt.subplots(10, 10)
fig.set_size_inches(13, 13)

for i, ax in enumerate(axies.flatten()):
    ax.imshow(cifar10.train.images[i].reshape((32, 32, 3)))
    ax.axis('off')
